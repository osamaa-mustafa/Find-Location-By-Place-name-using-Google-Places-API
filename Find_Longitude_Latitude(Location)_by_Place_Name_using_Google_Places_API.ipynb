# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: Bahria University, Lahore
# Retrieving http://py4e-data.dr-chuck.net/json?address=Bahria+University%2C+Lahore&key=42
# Retrieved 3135 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "47-C",
#                     "short_name": "47-C",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Chaudhry Rehmat Ali Underpass",
#                     "short_name": "Chaudhry Rehmat Ali Underpass",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Civic Centre",
#                     "short_name": "Civic Centre",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Block D 2",
#                     "short_name": "Block D 2",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_3"
#                     ]
#                 },
#                 {
#                     "long_name": "Phase 1",
#                     "short_name": "Phase 1",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_2"
#                     ]
#                 },
#                 {
#                     "long_name": "Johar Town",
#                     "short_name": "Johar Town",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_1"
#                     ]
#                 },
#                 {
#                     "long_name": "Lahore",
#                     "short_name": "Lahore",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Lahore City",
#                     "short_name": "Lahore City",
#                     "types": [
#                         "administrative_area_level_3",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Lahore",
#                     "short_name": "Lahore",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Punjab",
#                     "short_name": "Punjab",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Pakistan",
#                     "short_name": "PK",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "54600",
#                     "short_name": "54600",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "47-C Chaudhry Rehmat Ali Underpass, Civic Centre Block D 2 Phase 1 Johar Town, Lahore, Punjab 54600, Pakistan",
#             "geometry": {
#                 "location": {
#                     "lat": 31.4585245,
#                     "lng": 74.2886375
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 31.4598734802915,
#                         "lng": 74.2899864802915
#                     },
#                     "southwest": {
#                         "lat": 31.4571755197085,
#                         "lng": 74.28728851970848
#                     }
#                 }
#             },
#             "place_id": "ChIJzZhzHV4BGTkRZHqBTaxbVwM",
#             "plus_code": {
#                 "compound_code": "F75Q+CF Lahore, Pakistan",
#                 "global_code": "8J3PF75Q+CF"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "university"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat 31.4585245 lng 74.2886375
# 47-C Chaudhry Rehmat Ali Underpass, Civic Centre Block D 2 Phase 1 Johar Town, Lahore, Punjab 54600, Pakistan
